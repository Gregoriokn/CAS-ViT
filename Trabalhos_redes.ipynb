# %% [markdown]
# Trabalho de RN
# https://github.com/Gregoriokn/CAS-ViT.git
#
# Sua tarefa consiste construir uma versão do CAS-Vit e colocar adapters em cada bloco da arquitetura do CAS-Vit.
#
#  A rede CAS-Vit deverá ser congelada e somente os adapters deverão ser treináveis.
#
#  - Construção do dataset: coletar imagens com o seu celular com pelo menos 200 exemplos de cada classe. As classes são de livre escolha. Fazer split de treino, validação e teste com as seguintes proporções (70%,15%,15%)
#
# - Adaptação do código: Alterar a arquitetura do CAS-VIT para permitir o uso de adapters. (veja exemplos de como fazer isso em https://github.com/sun-hailong/CVPR24-Ease/blob/main/backbone/vit_ease.py nas funções de forward train e forward test)
#
# - Avaliação experimental:
#          Modelo cas-vit: fazer finetunning do cas-vit com o seu conjunto de dados
#          Modelo cas-vit+adapter: fazer finetunning do cas-vit+adapter com o seu conjunto de dados
#          Avaliação 1: avaliar os dois modelos  no seu conjunto de teste construído por você e apresentar o classification_report (https://scikit-learn.org/1.5/modules/generated/sklearn.metrics.classification_report.html) .
#         Avaliação 2: avaliar os dois modelos no conjunto ImageNet-A do link https://github.com/sun-hailong/CVPR24-Ease e apresentar o classification report
#         Fazer uma breve discussão dos resultados.
#
# - Entrega:
#       - github com os códigos e resultados
#       - vídeo de 10 mim explicando o código adaptado e os principais resultados.

# %%
# !pip install torch torchvision
# !pip install torch==1.8.0+cu101 torchvision==0.9.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install timm==0.5.4
# !pip install mmcv-full==1.5.3 -f https://download.openmmlab.com/mmcv/dist/cu101/torch1.8.0/index.html
# !pip install mmdet==2.24.0
# !pip install mmsegmentation==0.24.0
# Out:
# ...
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.8.0+cu101 (from versions: 1.9.0, 1.9.1, 1.10.0, 1.10.1, 1.10.2, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1)
# ERROR: No matching distribution found for torch==1.8.0+cu101
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu101/torch1.8.0/index.html
# ...
#   Using cached mmcv-full-1.5.3.tar.gz (547 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [1576 lines of output]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
# !git clone https://github.com/Gregoriokn/CAS-ViT.git
# Out:
# Cloning into 'CAS-ViT'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 158 (delta 55), reused 150 (delta 50), pack-reused 0 (from 0)
# Receiving objects: 100% (158/158), 5.23 MiB | 11.24 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
import os

# %%
# !git clone https://github.com/JorgeCecatto/LowRCAS-ViT.git
# Out:
# Cloning into 'LowRCAS-ViT'...
# remote: Enumerating objects: 199, done.
# remote: Counting objects: 100% (199/199), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 199 (delta 79), reused 177 (delta 61), pack-reused 0 (from 0)
# Receiving objects: 100% (199/199), 5.24 MiB | 11.84 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
main_dir = "LowRCAS-ViT/classification"
os.chdir('..')

# %%
# !ls
# Out:
# Classes               Trabalhos_redes.ipynb casvit_output
# LICENSE               ambiente.yml          classification
# LowRCAS-ViT           assets                detection
# MODEL_ZOO.md          best_model.pth        requirements.txt
# README.md             cas-vit-xs.pth        segmentation

# %%
import torch
torch.backends.mps.is_available()
# Out:
# True

# %%
# !python classification/fine_tune.py  --data_path Classes/ --batch_size 32 --input_size 384 --finetune cas-vit-xs.pth --lr 5e-5 --nb_classes 3  --model rcvit_xs --device mps
# Out:
# Running on mps
# RCvit
# /Users/gregorio/Documents/Mestrado/RedesNeurais/CAS-ViT/classification/fine_tune.py:247: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !python classification/fine_tune.py  --data_path Classes/ --batch_size 32 --input_size 384 --finetune cas-vit-xs.pth --lr 5e-5 --nb_classes 3  --model rcvit_xs --device mps --adapters
# Out:
# Running on mps
# RCvitAdapter
# ...

# %%
# !python classification/fine_tune.py  --data_path imagenet-a/ --batch_size 16 --input_size 224 --finetune cas-vit-xs.pth --lr 5e-5 --nb_classes 200  --model rcvit_xs --device mps
# Out:
# Numero de classes:3
# 473
# 389
# 83
# 84
# Running on mps
# RCvit
# ...

# %%
# !python classification/fine_tune.py  --data_path imagenet-a --batch_size 32 --input_size 384 --finetune cas-vit-xs.pth --lr 5e-5 --nb_classes 3  --model rcvit_xs --device mps --adapters
